# %%
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import keras
from keras.models import Sequential
from keras.layers import Conv2D, Lambda, MaxPooling2D # convolution layers
from keras.layers import Dense, Dropout, Flatten # core layers
from keras.layers import BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical

# %%
import os
import cv2

def resize_image(image_path):
    # Load the image and resize it to 128,128
    img = cv2.imread(image_path)
    img = cv2.resize(img, (128, 128), interpolation = cv2.INTER_AREA)
    return img

def read_dataset(dataset_path):
    # Create a list to store all the images
    images = []
    # Create a list to store the labels
    labels = []
    # Loop through the folders in the dataset path
    for folder in os.listdir(dataset_path):
        # Check if the folder is either 'Testing' or 'Training'
        if folder in ['Testing', 'Training']:
            # Create the path to the folder
            folder_path = os.path.join(dataset_path, folder)
            # Loop through the sub-folders in the folder
            for sub_folder in os.listdir(folder_path):
                # Check if the sub-folder is one of the four categories
                if sub_folder in ['glioma', 'meningioma', 'notumor', 'pituitary']:
                    # Create the path to the sub-folder
                    sub_folder_path = os.path.join(folder_path, sub_folder)
                    # Loop through the images in the sub-folder
                    for image_file in os.listdir(sub_folder_path):
                        # Check if the image is a .jpg file
                        if image_file.endswith('.jpg'):
                            # Create the path to the image
                            image_path = os.path.join(sub_folder_path, image_file)
                            # Resize the image and add it to the list of images
                            images.append(resize_image(image_path))
                            # Add the label to the list of labels
                            labels.append(sub_folder)
    return images, labels

# %%
# Call the read_dataset function to read the dataset
images, labels = read_dataset('/kaggle/input/brain-tumor-mri-dataset/')

# %%
target = ['glioma', 'meningioma', 'notumor', 'pituitary']

def text_to_index(text_labels):
    index_labels = []
    for label in text_labels:
        index_labels.append(target.index(label))
    return index_labels

labels = text_to_index(labels)

# %%
images=np.array(images)
labels=np.array(labels)
print(images.shape,labels.shape)
images = images / 255.0
# Out:
# (7023, 128, 128, 3) (7023,)

# %%
print(labels)
# Out:
# [3 3 3 ... 0 0 0]

# %%
from sklearn.model_selection import train_test_split
# Split the images and labels into training and testing sets, with a  test size
X_train, X_test, y_train, y_test = train_test_split(images,labels, test_size=0.2, random_state=42,stratify=labels)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (5618, 128, 128, 3) (1405, 128, 128, 3) (5618,) (1405,)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, Flatten, GlobalAveragePooling2D, BatchNormalization, Conv2D, MaxPooling2D
from tensorflow.keras.regularizers import l2,l1
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
from keras.applications.inception_v3 import InceptionV3

# Load the InceptionV3 model pre-trained on ImageNet without the top layers
base_model = InceptionV3(input_shape=(128, 128, 3), include_top=False, weights='imagenet')
# Freeze the weights of the base model to prevent them from being updated during training
for layer in base_model.layers:
    layer.trainable = True

# %%
x =base_model.output
# Add remaining layers
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu', kernel_regularizer=l2(0.01))(x)
predictions = Dense(4, activation='softmax')(x)

# Define the model
model = Model(inputs=base_model.input, outputs=predictions)

# %%
adam = Adam(lr=0.005)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
import tensorflow as tf
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

checkpoint = ModelCheckpoint('best_model.h5', save_best_only=True)
early_stop = EarlyStopping(patience=20, restore_best_weights=True)
tensorboard = TensorBoard(log_dir='./logs')

# %%
y_train = to_categorical(y_train)
print(f"Label size {y_train.shape}")
y_test = to_categorical(y_test)
print(f"Label size {y_test.shape}")
# Out:
# Label size (5618, 4)
# Label size (1405, 4)

# %%
from keras.preprocessing.image import ImageDataGenerator

# Create an instance of ImageDataGenerator with rotation and flip parameters
datagen = ImageDataGenerator(rotation_range=15, horizontal_flip=True, vertical_flip=True)
# Fit the generator to your training data
datagen.fit(X_train)

# %%
import time

# start time
start_time = time.time()


history = model.fit(datagen.flow(X_train, y_train, batch_size=32), validation_data=(X_test, y_test), epochs=100, batch_size=32, callbacks=
100
# 176/176 [==============================] - 28s 159ms/step - loss: 0.0301 - accuracy: 0.9934 - val_loss: 0.0787 - val_accuracy: 0.9801
# Epoch 74/100
# 176/176 [==============================] - 28s 159ms/step - loss: 0.0176 - accuracy: 0.9968 - val_loss: 0.0706 - val_accuracy: 0.9794
# Epoch 75/100
# 176/176 [==============================] - 28s 160ms/step - loss: 0.0492 - accuracy: 0.9883 - val_loss: 0.1143 - val_accuracy: 0.9665
# Epoch 76/100
# 176/176 [==============================] - 28s 158ms/step - loss: 0.0346 - accuracy: 0.9918 - val_loss: 0.0827 - val_accuracy: 0.9722
# Epoch 77/100
# 176/176 [==============================] - 28s 159ms/step - loss: 0.0186 - accuracy: 0.9956 - val_loss: 0.0884 - val_accuracy: 0.9772
# Epoch 78/100
# 176/176 [==============================] - 28s 158ms/step - loss: 0.0564 - accuracy: 0.9897 - val_loss: 0.3913 - val_accuracy: 0.9075
# Epoch 79/100
# 176/176 [==============================] - 27s 155ms/step - loss: 0.0517 - accuracy: 0.9881 - val_loss: 0.2269 - val_accuracy: 0.9388
# Epoch 80/100
# 176/176 [==============================] - 28s 159ms/step - loss: 0.0393 - accuracy: 0.9941 - val_loss: 0.3595 - val_accuracy: 0.9189
# Epoch 81/100
# 176/176 [==============================] - 28s 157ms/step - loss: 0.0615 - accuracy: 0.9891 - val_loss: 0.3598 - val_accuracy: 0.9132
# Epoch 82/100
# 176/176 [==============================] - 28s 158ms/step - loss: 0.0417 - accuracy: 0.9913 - val_loss: 0.0640 - val_accuracy: 0.9865
# Epoch 83/100
# 176/176 [==============================] - 27s 156ms/step - loss: 0.0210 - accuracy: 0.9961 - val_loss: 0.0488 - val_accuracy: 0.9865
# Epoch 84/100
# 176/176 [==============================] - 28s 159ms/step - loss: 0.0182 - accuracy: 0.9972 - val_loss: 0.0783 - val_accuracy: 0.9851
# Epoch 85/100
# 176/176 [==============================] - 28s 159ms/step - loss: 0.0207 - accuracy: 0.9956 - val_loss: 0.0730 - val_accuracy: 0.9779
# Epoch 86/100
# 176/176 [==============================] - 28s 159ms/step - loss: 0.0405 - accuracy: 0.9915 - val_loss: 0.3221 - val_accuracy: 0.9160
# Epoch 87/100
# 176/176 [==============================] - 28s 158ms/step - loss: 0.0259 - accuracy: 0.9948 - val_loss: 0.0814 - val_accuracy: 0.9794
# Epoch 88/100
# 176/176 [==============================] - 28s 159ms/step - loss: 0.0168 - accuracy: 0.9964 - val_loss: 0.0513 - val_accuracy: 0.9865
# Epoch 89/100
# 176/176 [==============================] - 28s 158ms/step - loss: 0.0230 - accuracy: 0.9956 - val_loss: 0.1552 - val_accuracy: 0.9601
# Epoch 90/100
# 176/176 [==============================] - 28s 160ms/step - loss: 0.0609 - accuracy: 0.9881 - val_loss: 0.0522 - val_accuracy: 0.9879
# Epoch 91/100
# 176/176 [==============================] - 28s 156ms/step - loss: 0.0233 - accuracy: 0.9956 - val_loss: 0.0937 - val_accuracy: 0.9772
# Total time taken:  2640.968079328537  seconds

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='train accuracy')
plt.plot(history.history['val_accuracy'], label='validation accuracy')
plt.legend()
plt.show()

plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='validation loss')
plt.legend()
plt.show()

# %%
y_pred = model.predict(X_test)
# Out:
# 44/44 [==============================] - 2s 27ms/step

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt

# Binarize the labels
y_test_bin = label_binarize(y_test, classes=[0, 1, 2, 3])

# Compute the predicted probabilities for each class
probas = model.predict(X_test)

# Compute the ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(4):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], probas[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test_bin.ravel(), probas.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Plot the ROC curves
plt.figure()
lw = 2
plt.plot(fpr["micro"], tpr["micro"], color='deeppink', lw=lw, label='micro-average ROC curve (area = {0:0.2f})'
         ''.format(roc_auc["micro"]))
colors = ['aqua', 'darkorange', 'cornflowerblue', 'purple']
for i, color in zip(range(4), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))
plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# 44/44 [==============================] - 1s 25ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report,accuracy_score,cohen_kappa_score

def evaluate_model(model, X_test, y_test, labels):
    # Make predictions on test data
    y_pred = model.predict(X_test)
    y_pred_labels = np.argmax(y_pred, axis=1)
    y_test_labels = np.argmax(y_test, axis=1)

    # Calculate the metrics
    loss, accuracy = model.evaluate(X_test, y_test)
    precision = accuracy_score(y_test_labels, y_pred_labels)*100
    kappa = cohen_kappa_score(y_test_labels, y_pred_labels)*100
    classification = classification_report(y_test_labels, y_pred_labels, target_names=labels)
    confusion = confusion_matrix(y_test_labels, y_pred_labels)
    accuracy=accuracy*100
    # Plot the confusion matrix
    fig, ax = plt.subplots(figsize=(10, 8))
    sns.heatmap(confusion, annot=True, cmap="Blues", fmt="d", xticklabels=labels, yticklabels=labels)
    ax.set_xlabel("Predicted Labels")
    ax.set_ylabel("True Labels")
    ax.set_title("Confusion Matrix")
    plt.show()

    # Print the classification report
    print("Classification Report:\n", classification)

    # Print the metrics
    print(f"Loss: {loss:.4f}")
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Kappa Score: {kappa:.4f}")
    return confusion, classification

# %%
target = ['glioma', 'meningioma', 'notumor', 'pituitary']
confusion, classification= evaluate_model(model, X_test, y_test, target)
# Out:
# 44/44 [==============================] - 1s 25ms/step
# 44/44 [==============================] - 1s 29ms/step - loss: 0.0450 - accuracy: 0.9858
# Classification Report:
#                precision    recall  f1-score   support
#
#       glioma       0.98      0.98      0.98       324
#   meningioma       0.98      0.96      0.97       329
#      notumor       1.00      1.00      1.00       400
#    pituitary       0.98      1.00      0.99       352
#
#     accuracy                           0.99      1405
#    macro avg       0.99      0.98      0.99      1405
# weighted avg       0.99      0.99      0.99      1405
#
# Loss: 0.0450
# Accuracy: 98.5765
# Precision: 98.5765
# Kappa Score: 98.0971

# %%
from tensorflow.keras.models import load_model
# Save the model to a file
model.save('inception-tf2.h5')

# %%
# Get the list of trainable layers in the model
trainable_layers = [layer for layer in model.layers if layer.trainable]

# Print the summary of trainable layers only
print("Trainable layers summary:")
for layer in trainable_layers:
    print(layer.name, layer.trainable, layer.output_shape)
# Out:
# Trainable layers summary:
# input_2 True [(None, 128, 128, 3)]
# conv2d_94 True (None, 63, 63, 32)
# batch_normalization_94 True (None, 63, 63, 32)
# activation_94 True (None, 63, 63, 32)
# conv2d_95 True (None, 61, 61, 32)
# batch_normalization_95 True (None, 61, 61, 32)
# activation_95 True (None, 61, 61, 32)
# conv2d_96 True (None, 61, 61, 64)
# batch_normalization_96 True (None, 61, 61, 64)
# activation_96 True (None, 61, 61, 64)
# max_pooling2d_4 True (None, 30, 30, 64)
# conv2d_97 True (None, 30, 30, 80)
# batch_normalization_97 True (None, 30, 30, 80)
# activation_97 True (None, 30, 30, 80)
# conv2d_98 True (None, 28, 28, 192)
# batch_normalization_98 True (None, 28, 28, 192)
# activation_98 True (None, 28, 28, 192)
# max_pooling2d_5 True (None, 13, 13, 192)
# conv2d_102 True (None, 13, 13, 64)
# batch_normalization_102 True (None, 13, 13, 64)
# activation_102 True (None, 13, 13, 64)
# conv2d_100 True (None, 13, 13, 48)
# conv2d_103 True (None, 13, 13, 96)
# batch_normalization_100 True (None, 13, 13, 48)
# batch_normalization_103 True (None, 13, 13, 96)
# activation_100 True (None, 13, 13, 48)
# activation_103 True (None, 13, 13, 96)
# average_pooling2d_9 True (None, 13, 13, 192)
# conv2d_99 True (None, 13, 13, 64)
# conv2d_101 True (None, 13, 13, 64)
# conv2d_104 True (None, 13, 13, 96)
# conv2d_105 True (None, 13, 13, 32)
# batch_normalization_99 True (None, 13, 13, 64)
# batch_normalization_101 True (None, 13, 13, 64)
# batch_normalization_104 True (None, 13, 13, 96)
# batch_normalization_105 True (None, 13, 13, 32)
# activation_99 True (None, 13, 13, 64)
# activation_101 True (None, 13, 13, 64)
# activation_104 True (None, 13, 13, 96)
# activation_105 True (None, 13, 13, 32)
# mixed0 True (None, 13, 13, 256)
# conv2d_109 True (None, 13, 13, 64)
# batch_normalization_109 True (None, 13, 13, 64)
# activation_109 True (None, 13, 13, 64)
# conv2d_107 True (None, 13, 13, 48)
# conv2d_110 True (None, 13, 13, 96)
# batch_normalization_107 True (None, 13, 13, 48)
# batch_normalization_110 True (None, 13, 13, 96)
# activation_107 True (None, 13, 13, 48)
# activation_110 True (None, 13, 13, 96)
# average_pooling2d_10 True (None, 13, 13, 256)
# conv2d_106 True (None, 13, 13, 64)
# conv2d_108 True (None, 13, 13, 64)
# conv2d_111 True (None, 13, 13, 96)
# conv2d_112 True (None, 13, 13, 64)
# batch_normalization_106 True (None, 13, 13, 64)
# batch_normalization_108 True (None, 13, 13, 64)
# batch_normalization_111 True (None, 13, 13, 96)
# batch_normalization_112 True (None, 13, 13, 64)
# activation_106 True (None, 13, 13, 64)
# activation_108 True (None, 13, 13, 64)
# activation_111 True (None, 13, 13, 96)
# activation_112 True (None, 13, 13, 64)
# mixed1 True (None, 13, 13, 288)
# conv2d_116 True (None, 13, 13, 64)
# batch_normalization_116 True (None, 13, 13, 64)
# activation_116 True (None, 13, 13, 64)
# conv2d_114 True (None, 13, 13, 48)
# conv2d_117 True (None, 13, 13, 96)
# batch_normalization_114 True (None, 13, 13, 48)
# batch_normalization_117 True (None, 13, 13, 96)
# activation_114 True (None, 13, 13, 48)
# activation_117 True (None, 13, 13, 96)
# average_pooling2d_11 True (None, 13, 13, 288)
# conv2d_113 True (None, 13, 13, 64)
# conv2d_115 True (None, 13, 13, 64)
# conv2d_118 True (None, 13, 13, 96)
# conv2d_119 True (None, 13, 13, 64)
# batch_normalization_113 True (None, 13, 13, 64)
# batch_normalization_115 True (None, 13, 13, 64)
# batch_normalization_118 True (None, 13, 13, 96)
# batch_normalization_119 True (None, 13, 13, 64)
# activation_113 True (None, 13, 13, 64)
# activation_115 True (None, 13, 13, 64)
# activation_118 True (None, 13, 13, 96)
# activation_119 True (None, 13, 13, 64)
# mixed2 True (None, 13, 13, 288)
# conv2d_121 True (None, 13, 13, 64)
# batch_normalization_121 True (None, 13, 13, 64)
# activation_121 True (None, 13, 13, 64)
# conv2d_122 True (None, 13, 13, 96)
# batch_normalization_122 True (None, 13, 13, 96)
# activation_122 True (None, 13, 13, 96)
# conv2d_120 True (None, 6, 6, 384)
# conv2d_123 True (None, 6, 6, 96)
# batch_normalization_120 True (None, 6, 6, 384)
# batch_normalization_123 True (None, 6, 6, 96)
# activation_120 True (None, 6, 6, 384)
# activation_123 True (None, 6, 6, 96)
# max_pooling2d_6 True (None, 6, 6, 288)
# mixed3 True (None, 6, 6, 768)
# conv2d_128 True (None, 6, 6, 128)
# batch_normalization_128 True (None, 6, 6, 128)
# activation_128 True (None, 6, 6, 128)
# conv2d_129 True (None, 6, 6, 128)
# batch_normalization_129 True (None, 6, 6, 128)
# activation_129 True (None, 6, 6, 128)
# conv2d_125 True (None, 6, 6, 128)
# conv2d_130 True (None, 6, 6, 128)
# batch_normalization_125 True (None, 6, 6, 128)
# batch_normalization_130 True (None, 6, 6, 128)
# activation_125 True (None, 6, 6, 128)
# activation_130 True (None, 6, 6, 128)
# conv2d_126 True (None, 6, 6, 128)
# conv2d_131 True (None, 6, 6, 128)
# batch_normalization_126 True (None, 6, 6, 128)
# batch_normalization_131 True (None, 6, 6, 128)
# activation_126 True (None, 6, 6, 128)
# activation_131 True (None, 6, 6, 128)
# average_pooling2d_12 True (None, 6, 6, 768)
# conv2d_124 True (None, 6, 6, 192)
# conv2d_127 True (None, 6, 6, 192)
# conv2d_132 True (None, 6, 6, 192)
# conv2d_133 True (None, 6, 6, 192)
# batch_normalization_124 True (None, 6, 6, 192)
# batch_normalization_127 True (None, 6, 6, 192)
# batch_normalization_132 True (None, 6, 6, 192)
# batch_normalization_133 True (None, 6, 6, 192)
# activation_124 True (None, 6, 6, 192)
# activation_127 True (None, 6, 6, 192)
# activation_132 True (None, 6, 6, 192)
# activation_133 True (None, 6, 6, 192)
# mixed4 True (None, 6, 6, 768)
# conv2d_138 True (None, 6, 6, 160)
# batch_normalization_138 True (None, 6, 6, 160)
# activation_138 True (None, 6, 6, 160)
# conv2d_139 True (None, 6, 6, 160)
# batch_normalization_139 True (None, 6, 6, 160)
# activation_139 True (None, 6, 6, 160)
# conv2d_135 True (None, 6, 6, 160)
# conv2d_140 True (None, 6, 6, 160)
# batch_normalization_135 True (None, 6, 6, 160)
# batch_normalization_140 True (None, 6, 6, 160)
# activation_135 True (None, 6, 6, 160)
# activation_140 True (None, 6, 6, 160)
# conv2d_136 True (None, 6, 6, 160)
# conv2d_141 True (None, 6, 6, 160)
# batch_normalization_136 True (None, 6, 6, 160)
# batch_normalization_141 True (None, 6, 6, 160)
# activation_136 True (None, 6, 6, 160)
# activation_141 True (None, 6, 6, 160)
# average_pooling2d_13 True (None, 6, 6, 768)
# conv2d_134 True (None, 6, 6, 192)
# conv2d_137 True (None, 6, 6, 192)
# conv2d_142 True (None, 6, 6, 192)
# conv2d_143 True (None, 6, 6, 192)
# batch_normalization_134 True (None, 6, 6, 192)
# batch_normalization_137 True (None, 6, 6, 192)
# batch_normalization_142 True (None, 6, 6, 192)
# batch_normalization_143 True (None, 6, 6, 192)
# activation_134 True (None, 6, 6, 192)
# activation_137 True (None, 6, 6, 192)
# activation_142 True (None, 6, 6, 192)
# activation_143 True (None, 6, 6, 192)
# mixed5 True (None, 6, 6, 768)
# conv2d_148 True (None, 6, 6, 160)
# batch_normalization_148 True (None, 6, 6, 160)
# activation_148 True (None, 6, 6, 160)
# conv2d_149 True (None, 6, 6, 160)
# batch_normalization_149 True (None, 6, 6, 160)
# activation_149 True (None, 6, 6, 160)
# conv2d_145 True (None, 6, 6, 160)
# conv2d_150 True (None, 6, 6, 160)
# batch_normalization_145 True (None, 6, 6, 160)
# batch_normalization_150 True (None, 6, 6, 160)
# activation_145 True (None, 6, 6, 160)
# activation_150 True (None, 6, 6, 160)
# conv2d_146 True (None, 6, 6, 160)
# conv2d_151 True (None, 6, 6, 160)
# batch_normalization_146 True (None, 6, 6, 160)
# batch_normalization_151 True (None, 6, 6, 160)
# activation_146 True (None, 6, 6, 160)
# activation_151 True (None, 6, 6, 160)
# average_pooling2d_14 True (None, 6, 6, 768)
# conv2d_144 True (None, 6, 6, 192)
# conv2d_147 True (None, 6, 6, 192)
# conv2d_152 True (None, 6, 6, 192)
# conv2d_153 True (None, 6, 6, 192)
# batch_normalization_144 True (None, 6, 6, 192)
# batch_normalization_147 True (None, 6, 6, 192)
# batch_normalization_152 True (None, 6, 6, 192)
# batch_normalization_153 True (None, 6, 6, 192)
# activation_144 True (None, 6, 6, 192)
# activation_147 True (None, 6, 6, 192)
# activation_152 True (None, 6, 6, 192)
# activation_153 True (None, 6, 6, 192)
# mixed6 True (None, 6, 6, 768)
# conv2d_158 True (None, 6, 6, 192)
# batch_normalization_158 True (None, 6, 6, 192)
# activation_158 True (None, 6, 6, 192)
# conv2d_159 True (None, 6, 6, 192)
# batch_normalization_159 True (None, 6, 6, 192)
# activation_159 True (None, 6, 6, 192)
# conv2d_155 True (None, 6, 6, 192)
# conv2d_160 True (None, 6, 6, 192)
# batch_normalization_155 True (None, 6, 6, 192)
# batch_normalization_160 True (None, 6, 6, 192)
# activation_155 True (None, 6, 6, 192)
# activation_160 True (None, 6, 6, 192)
# conv2d_156 True (None, 6, 6, 192)
# conv2d_161 True (None, 6, 6, 192)
# batch_normalization_156 True (None, 6, 6, 192)
# batch_normalization_161 True (None, 6, 6, 192)
# activation_156 True (None, 6, 6, 192)
# activation_161 True (None, 6, 6, 192)
# average_pooling2d_15 True (None, 6, 6, 768)
# conv2d_154 True (None, 6, 6, 192)
# conv2d_157 True (None, 6, 6, 192)
# conv2d_162 True (None, 6, 6, 192)
# conv2d_163 True (None, 6, 6, 192)
# batch_normalization_154 True (None, 6, 6, 192)
# batch_normalization_157 True (None, 6, 6, 192)
# batch_normalization_162 True (None, 6, 6, 192)
# batch_normalization_163 True (None, 6, 6, 192)
# activation_154 True (None, 6, 6, 192)
# activation_157 True (None, 6, 6, 192)
# activation_162 True (None, 6, 6, 192)
# activation_163 True (None, 6, 6, 192)
# mixed7 True (None, 6, 6, 768)
# conv2d_166 True (None, 6, 6, 192)
# batch_normalization_166 True (None, 6, 6, 192)
# activation_166 True (None, 6, 6, 192)
# conv2d_167 True (None, 6, 6, 192)
# batch_normalization_167 True (None, 6, 6, 192)
# activation_167 True (None, 6, 6, 192)
# conv2d_164 True (None, 6, 6, 192)
# conv2d_168 True (None, 6, 6, 192)
# batch_normalization_164 True (None, 6, 6, 192)
# batch_normalization_168 True (None, 6, 6, 192)
# activation_164 True (None, 6, 6, 192)
# activation_168 True (None, 6, 6, 192)
# conv2d_165 True (None, 2, 2, 320)
# conv2d_169 True (None, 2, 2, 192)
# batch_normalization_165 True (None, 2, 2, 320)
# batch_normalization_169 True (None, 2, 2, 192)
# activation_165 True (None, 2, 2, 320)
# activation_169 True (None, 2, 2, 192)
# max_pooling2d_7 True (None, 2, 2, 768)
# mixed8 True (None, 2, 2, 1280)
# conv2d_174 True (None, 2, 2, 448)
# batch_normalization_174 True (None, 2, 2, 448)
# activation_174 True (None, 2, 2, 448)
# conv2d_171 True (None, 2, 2, 384)
# conv2d_175 True (None, 2, 2, 384)
# batch_normalization_171 True (None, 2, 2, 384)
# batch_normalization_175 True (None, 2, 2, 384)
# activation_171 True (None, 2, 2, 384)
# activation_175 True (None, 2, 2, 384)
# conv2d_172 True (None, 2, 2, 384)
# conv2d_173 True (None, 2, 2, 384)
# conv2d_176 True (None, 2, 2, 384)
# conv2d_177 True (None, 2, 2, 384)
# average_pooling2d_16 True (None, 2, 2, 1280)
# conv2d_170 True (None, 2, 2, 320)
# batch_normalization_172 True (None, 2, 2, 384)
# batch_normalization_173 True (None, 2, 2, 384)
# batch_normalization_176 True (None, 2, 2, 384)
# batch_normalization_177 True (None, 2, 2, 384)
# conv2d_178 True (None, 2, 2, 192)
# batch_normalization_170 True (None, 2, 2, 320)
# activation_172 True (None, 2, 2, 384)
# activation_173 True (None, 2, 2, 384)
# activation_176 True (None, 2, 2, 384)
# activation_177 True (None, 2, 2, 384)
# batch_normalization_178 True (None, 2, 2, 192)
# activation_170 True (None, 2, 2, 320)
# mixed9_0 True (None, 2, 2, 768)
# concatenate_2 True (None, 2, 2, 768)
# activation_178 True (None, 2, 2, 192)
# mixed9 True (None, 2, 2, 2048)
# conv2d_183 True (None, 2, 2, 448)
# batch_normalization_183 True (None, 2, 2, 448)
# activation_183 True (None, 2, 2, 448)
# conv2d_180 True (None, 2, 2, 384)
# conv2d_184 True (None, 2, 2, 384)
# batch_normalization_180 True (None, 2, 2, 384)
# batch_normalization_184 True (None, 2, 2, 384)
# activation_180 True (None, 2, 2, 384)
# activation_184 True (None, 2, 2, 384)
# conv2d_181 True (None, 2, 2, 384)
# conv2d_182 True (None, 2, 2, 384)
# conv2d_185 True (None, 2, 2, 384)
# conv2d_186 True (None, 2, 2, 384)
# average_pooling2d_17 True (None, 2, 2, 2048)
# conv2d_179 True (None, 2, 2, 320)
# batch_normalization_181 True (None, 2, 2, 384)
# batch_normalization_182 True (None, 2, 2, 384)
# batch_normalization_185 True (None, 2, 2, 384)
# batch_normalization_186 True (None, 2, 2, 384)
# conv2d_187 True (None, 2, 2, 192)
# batch_normalization_179 True (None, 2, 2, 320)
# activation_181 True (None, 2, 2, 384)
# activation_182 True (None, 2, 2, 384)
# activation_185 True (None, 2, 2, 384)
# activation_186 True (None, 2, 2, 384)
# batch_normalization_187 True (None, 2, 2, 192)
# activation_179 True (None, 2, 2, 320)
# mixed9_1 True (None, 2, 2, 768)
# concatenate_3 True (None, 2, 2, 768)
# activation_187 True (None, 2, 2, 192)
# mixed10 True (None, 2, 2, 2048)
# global_average_pooling2d True (None, 2048)
# dense True (None, 1024)
# dense_1 True (None, 4)

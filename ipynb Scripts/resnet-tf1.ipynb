# %%
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import keras
from keras.models import Sequential
from keras.layers import Conv2D, Lambda, MaxPooling2D # convolution layers
from keras.layers import Dense, Dropout, Flatten # core layers
from keras.layers import BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical

# %%
import os
import cv2

def resize_image(image_path):
    # Load the image and resize it to 128,128
    img = cv2.imread(image_path)
    img = cv2.resize(img, (128, 128), interpolation = cv2.INTER_AREA)
    return img

def read_dataset(dataset_path):
    # Create a list to store all the images
    images = []
    # Create a list to store the labels
    labels = []
    # Loop through the folders in the dataset path
    for folder in os.listdir(dataset_path):
        # Check if the folder is either 'Testing' or 'Training'
        if folder in ['Testing', 'Training']:
            # Create the path to the folder
            folder_path = os.path.join(dataset_path, folder)
            # Loop through the sub-folders in the folder
            for sub_folder in os.listdir(folder_path):
                # Check if the sub-folder is one of the four categories
                if sub_folder in ['glioma', 'meningioma', 'notumor', 'pituitary']:
                    # Create the path to the sub-folder
                    sub_folder_path = os.path.join(folder_path, sub_folder)
                    # Loop through the images in the sub-folder
                    for image_file in os.listdir(sub_folder_path):
                        # Check if the image is a .jpg file
                        if image_file.endswith('.jpg'):
                            # Create the path to the image
                            image_path = os.path.join(sub_folder_path, image_file)
                            # Resize the image and add it to the list of images
                            images.append(resize_image(image_path))
                            # Add the label to the list of labels
                            labels.append(sub_folder)
    return images, labels

# %%
# Call the read_dataset function to read the dataset
images, labels = read_dataset('/kaggle/input/brain-tumor-mri-dataset/')

# %%
target = ['glioma', 'meningioma', 'notumor', 'pituitary']

def text_to_index(text_labels):
    index_labels = []
    for label in text_labels:
        index_labels.append(target.index(label))
    return index_labels

labels = text_to_index(labels)

# %%
images=np.array(images)
labels=np.array(labels)
print(images.shape,labels.shape)
images = images / 255.0
# Out:
# (7023, 128, 128, 3) (7023,)

# %%
print(labels)
# Out:
# [3 3 3 ... 0 0 0]

# %%
from sklearn.model_selection import train_test_split
# Split the images and labels into training and testing sets, with a  test size
X_train, X_test, y_train, y_test = train_test_split(images,labels, test_size=0.2, random_state=42,stratify=labels)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (5618, 128, 128, 3) (1405, 128, 128, 3) (5618,) (1405,)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, Flatten, GlobalAveragePooling2D, BatchNormalization, Conv2D, MaxPooling2D
from tensorflow.keras.regularizers import l2,l1
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
from keras.applications import ResNet50

# Load the pre-trained ResNet50 model without top layers
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(128,128,3))

# Freeze the weights of the base model to prevent them from being updated during training
for layer in base_model.layers:
    layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 0s 0us/step

# %%
x =base_model.output
# Add remaining layers
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu', kernel_regularizer=l2(0.01))(x)
predictions = Dense(4, activation='softmax')(x)

# Define the model
model = Model(inputs=base_model.input, outputs=predictions)

# %%
adam = Adam(lr=0.005)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
import tensorflow as tf
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

checkpoint = ModelCheckpoint('best_model.h5', save_best_only=True)
early_stop = EarlyStopping(patience=20, restore_best_weights=True)
tensorboard = TensorBoard(log_dir='./logs')

# %%
y_train = to_categorical(y_train)
print(f"Label size {y_train.shape}")
y_test = to_categorical(y_test)
print(f"Label size {y_test.shape}")
# Out:
# Label size (5618, 4)
# Label size (1405, 4)

# %%
from keras.preprocessing.image import ImageDataGenerator

# Create an instance of ImageDataGenerator with rotation and flip parameters
datagen = ImageDataGenerator(rotation_range=15, horizontal_flip=True, vertical_flip=True)
# Fit the generator to your training data
datagen.fit(X_train)

# %%
import time

# start time
start_time = time.time()


history = model.fit(datagen.flow(X_train, y_train, batch_size=32), validation_data=(X_test, y_test), epochs=100, batch_size=32, callbacks=[checkpoint, early_stop])

# end time
end_time = time.time()

# calculate total time taken
total_time = end_time - start_time

print("Total time taken: ", total_time, " seconds")
# Out:
# Epoch 1/100
# 176/176 [==============================] - 38s 155ms/step - loss: 2.3004 - accuracy: 0.4286 - val_loss: 1.2830 - val_accuracy: 0.3829
# Epoch 2/100
# 176/176 [==============================] - 25s 143ms/step - loss: 1.2168 - accuracy: 0.4986 - val_loss: 1.1592 - val_accuracy: 0.5423
# Epoch 3/100
# 176/176 [==============================] - 24s 137ms/step - loss: 1.1990 - accuracy: 0.5174 - val_loss: 1.1746 - val_accuracy: 0.5110
# Epoch 4/100
# 176/176 [==============================] - 25s 144ms/step - loss: 1.1726 - accuracy: 0.5317 - val_loss: 1.1593 - val_accuracy: 0.5345
# Epoch 5/100
# 176/176 [==============================] - 24s 137ms/step - loss: 1.1522 - accuracy: 0.5384 - val_loss: 1.2004 - val_accuracy: 0.4947
# Epoch 6/100
# 176/176 [==============================] - 24s 138ms/step - loss: 1.1426 - accuracy: 0.5514 - val_loss: 1.1150 - val_accuracy: 0.5566
# Epoch 7/100
# 176/176 [==============================] - 25s 142ms/step - loss: 1.1384 - accuracy: 0.5457 - val_loss: 1.0803 - val_accuracy: 0.5915
# Epoch 8/100
# 176/176 [==============================] - 24s 138ms/step - loss: 1.1209 - accuracy: 0.5845 - val_loss: 1.3385 - val_accuracy: 0.4093
# Epoch 9/100
# 176/176 [==============================] - 25s 139ms/step - loss: 1.1371 - accuracy: 0.5457 - val_loss: 1.0979 - val_accuracy: 0.5708
# Epoch 10/100
# 176/176 [==============================] - 25s 142ms/step - loss: 1.1278 - accuracy: 0.5600 - val_loss: 1.1485 - val_accuracy: 0.5288
# Epoch 11/100
# 176/176 [==============================] - 25s 141ms/step - loss: 1.1003 - accuracy: 0.5769 - val_loss: 1.0299 - val_accuracy: 0.6185
# Epoch 12/100
# 176/176 [==============================] - 24s 139ms/step - loss: 1.1223 - accuracy: 0.5545 - val_loss: 1.1900 - val_accuracy: 0.4940
# Epoch 13/100
# 176/176 [==============================] - 25s 144ms/step - loss: 1.0791 - accuracy: 0.5975 - val_loss: 1.0930 - val_accuracy: 0.5580
# Epoch 14/100
# 176/176 [==============================] - 25s 143ms/step - loss: 1.0644 - accuracy: 0.6034 - val_loss: 1.0506 - val_accuracy: 0.5858
# Epoch 15/100
# 176/176 [==============================] - 25s 140ms/step - loss: 1.0423 - accuracy: 0.6248 - val_loss: 1.0545 - val_accuracy: 0.5972
# Epoch 16/100
# 176/176 [==============================] - 26s 145ms/step - loss: 1.0460 - accuracy: 0.6063 - val_loss: 0.9661 - val_accuracy: 0.6463
# Epoch 17/100
# 176/176 [==============================] - 24s 137ms/step - loss: 1.0289 - accuracy: 0.6194 - val_loss: 1.1368 - val_accuracy: 0.5367
# Epoch 18/100
# 176/176 [==============================] - 23s 133ms/step - loss: 1.0218 - accuracy: 0.6282 - val_loss: 1.0364 - val_accuracy: 0.5708
# Epoch 19/100
# 176/176 [==============================] - 26s 146ms/step - loss: 1.0357 - accuracy: 0.6123 - val_loss: 0.9549 - val_accuracy: 0.6584
# Epoch 20/100
# 176/176 [==============================] - 25s 144ms/step - loss: 0.9934 - accuracy: 0.6379 - val_loss: 1.0404 - val_accuracy: 0.5922
# Epoch 21/100
# 176/176 [==============================] - 24s 136ms/step - loss: 1.0050 - accuracy: 0.6285 - val_loss: 0.9799 - val_accuracy: 0.6256
# Epoch 22/100
# 176/176 [==============================] - 24s 138ms/step - loss: 0.9886 - accuracy: 0.6362 - val_loss: 0.9883 - val_accuracy: 0.6235
# Epoch 23/100
# 176/176 [==============================] - 25s 142ms/step - loss: 0.9917 - accuracy: 0.6317 - val_loss: 1.2088 - val_accuracy: 0.5053
# Epoch 24/100
# 176/176 [==============================] - 24s 135ms/step - loss: 0.9881 - accuracy: 0.6381 - val_loss: 1.1210 - val_accuracy: 0.5246
# Epoch 25/100
# 176/176 [==============================] - 24s 135ms/step - loss: 0.9803 - accuracy: 0.6390 - val_loss: 1.2294 - val_accuracy: 0.4868
# Epoch 26/100
# 176/176 [==============================] - 24s 137ms/step - loss: 0.9789 - accuracy: 0.6349 - val_loss: 0.9854 - val_accuracy: 0.6342
# Epoch 27/100
# 176/176 [==============================] - 24s 136ms/step - loss: 0.9813 - accuracy: 0.6301 - val_loss: 1.0356 - val_accuracy: 0.5972
# Epoch 28/100
# 176/176 [==============================] - 25s 140ms/step - loss: 0.9610 - accuracy: 0.6435 - val_loss: 1.1220 - val_accuracy: 0.5317
# Epoch 29/100
# 176/176 [==============================] - 25s 141ms/step - loss: 0.9605 - accuracy: 0.6415 - val_loss: 0.9158 - val_accuracy: 0.6633
# Epoch 30/100
# 176/176 [==============================] - 25s 142ms/step - loss: 0.9479 - accuracy: 0.6529 - val_loss: 0.9267 - val_accuracy: 0.6427
# Epoch 31/100
# 176/176 [==============================] - 25s 142ms/step - loss: 0.9526 - accuracy: 0.6483 - val_loss: 0.8753 - val_accuracy: 0.6932
# Epoch 32/100
# 176/176 [==============================] - 24s 135ms/step - loss: 0.9478 - accuracy: 0.6506 - val_loss: 1.0005 - val_accuracy: 0.6085
# Epoch 33/100
# 176/176 [==============================] - 24s 136ms/step - loss: 0.9425 - accuracy: 0.6524 - val_loss: 1.0466 - val_accuracy: 0.5872
# Epoch 34/100
# 176/176 [==============================] - 25s 141ms/step - loss: 0.9511 - accuracy: 0.6458 - val_loss: 0.8981 - val_accuracy: 0.6605
# Epoch 35/100
# 176/176 [==============================] - 23s 131ms/step - loss: 0.9381 - accuracy: 0.6575 - val_loss: 0.9022 - val_accuracy: 0.6598
# Epoch 36/100
# 176/176 [==============================] - 25s 139ms/step - loss: 0.9328 - accuracy: 0.6586 - val_loss: 0.8654 - val_accuracy: 0.6868
# Epoch 37/100
# 176/176 [==============================] - 25s 141ms/step - loss: 0.9238 - accuracy: 0.6659 - val_loss: 1.1380 - val_accuracy: 0.5238
# Epoch 38/100
# 176/176 [==============================] - 25s 141ms/step - loss: 0.9303 - accuracy: 0.6561 - val_loss: 0.9177 - val_accuracy: 0.6569
# Epoch 39/100
# 176/176 [==============================] - 24s 139ms/step - loss: 0.9302 - accuracy: 0.6545 - val_loss: 0.9861 - val_accuracy: 0.6028
# Epoch 40/100
# 176/176 [==============================] - 26s 145ms/step - loss: 0.9175 - accuracy: 0.6661 - val_loss: 0.8577 - val_accuracy: 0.7011
# Epoch 41/100
# 176/176 [==============================] - 24s 136ms/step - loss: 0.9157 - accuracy: 0.6650 - val_loss: 0.9707 - val_accuracy: 0.6235
# Epoch 42/100
# 176/176 [==============================] - 24s 134ms/step - loss: 0.9199 - accuracy: 0.6641 - val_loss: 0.9064 - val_accuracy: 0.6527
# Epoch 43/100
# 176/176 [==============================] - 23s 133ms/step - loss: 0.9204 - accuracy: 0.6622 - val_loss: 0.9253 - val_accuracy: 0.6427
# Epoch 44/100
# 176/176 [==============================] - 24s 136ms/step - loss: 0.9101 - accuracy: 0.6634 - val_loss: 0.8713 - val_accuracy: 0.6648
# Epoch 45/100
# 176/176 [==============================] - 23s 133ms/step - loss: 0.9229 - accuracy: 0.6524 - val_loss: 1.1042 - val_accuracy: 0.5288
# Epoch 46/100
# 176/176 [==============================] - 23s 133ms/step - loss: 0.9271 - accuracy: 0.6561 - val_loss: 0.9147 - val_accuracy: 0.6569
# Epoch 47/100
# 176/176 [==============================] - 24s 136ms/step - loss: 0.9179 - accuracy: 0.6590 - val_loss: 0.8999 - val_accuracy: 0.6548
# Epoch 48/100
# 176/176 [==============================] - 23s 130ms/step - loss: 0.9131 - accuracy: 0.6664 - val_loss: 0.9661 - val_accuracy: 0.6185
# Epoch 49/100
# 176/176 [==============================] - 23s 133ms/step - loss: 0.9018 - accuracy: 0.6707 - val_loss: 0.9518 - val_accuracy: 0.6299
# Epoch 50/100
# 176/176 [==============================] - 24s 134ms/step - loss: 0.9059 - accuracy: 0.6670 - val_loss: 0.9147 - val_accuracy: 0.6448
# Epoch 51/100
# 176/176 [==============================] - 24s 134ms/step - loss: 0.8948 - accuracy: 0.6716 - val_loss: 0.8552 - val_accuracy: 0.6811
# Epoch 52/100
# 176/176 [==============================] - 24s 136ms/step - loss: 0.8944 - accuracy: 0.6752 - val_loss: 0.8751 - val_accuracy: 0.6569
# Epoch 53/100
# 176/176 [==============================] - 24s 138ms/step - loss: 0.8921 - accuracy: 0.6744 - val_loss: 0.9117 - val_accuracy: 0.6306
# Epoch 54/100
# 176/176 [==============================] - 24s 139ms/step - loss: 0.8920 - accuracy: 0.6684 - val_loss: 1.0148 - val_accuracy: 0.6014
# Epoch 55/100
# 176/176 [==============================] - 23s 133ms/step - loss: 0.8833 - accuracy: 0.6735 - val_loss: 0.8559 - val_accuracy: 0.6932
# Epoch 56/100
# 176/176 [==============================] - 23s 131ms/step - loss: 0.8743 - accuracy: 0.6842 - val_loss: 0.8851 - val_accuracy: 0.6726
# Epoch 57/100
# 176/176 [==============================] - 25s 140ms/step - loss: 0.8950 - accuracy: 0.6659 - val_loss: 0.9719 - val_accuracy: 0.6085
# Epoch 58/100
# 176/176 [==============================] - 25s 143ms/step - loss: 0.9058 - accuracy: 0.6689 - val_loss: 0.8228 - val_accuracy: 0.7053
# Epoch 59/100
# 176/176 [==============================] - 24s 139ms/step - loss: 0.8736 - accuracy: 0.6865 - val_loss: 0.8773 - val_accuracy: 0.6762
# Epoch 60/100
# 176/176 [==============================] - 24s 137ms/step - loss: 0.8856 - accuracy: 0.6734 - val_loss: 0.8246 - val_accuracy: 0.7004
# Epoch 61/100
# 176/176 [==============================] - 25s 140ms/step - loss: 0.8812 - accuracy: 0.6695 - val_loss: 0.8374 - val_accuracy: 0.6947
# Epoch 62/100
# 176/176 [==============================] - 23s 132ms/step - loss: 0.8807 - accuracy: 0.6775 - val_loss: 0.9094 - val_accuracy: 0.6520
# Epoch 63/100
# 176/176 [==============================] - 23s 131ms/step - loss: 0.8844 - accuracy: 0.6682 - val_loss: 0.8777 - val_accuracy: 0.6769
# Epoch 64/100
# 176/176 [==============================] - 24s 138ms/step - loss: 0.8823 - accuracy: 0.6753 - val_loss: 0.8175 - val_accuracy: 0.7167
# Epoch 65/100
# 176/176 [==============================] - 24s 134ms/step - loss: 0.8718 - accuracy: 0.6780 - val_loss: 0.9362 - val_accuracy: 0.6456
# Epoch 66/100
# 176/176 [==============================] - 24s 138ms/step - loss: 0.8863 - accuracy: 0.6743 - val_loss: 0.8498 - val_accuracy: 0.6918
# Epoch 67/100
# 176/176 [==============================] - 23s 131ms/step - loss: 0.8832 - accuracy: 0.6723 - val_loss: 0.8225 - val_accuracy: 0.7004
# Epoch 68/100
# 176/176 [==============================] - 24s 134ms/step - loss: 0.8712 - accuracy: 0.6803 - val_loss: 0.8401 - val_accuracy: 0.6918
# Epoch 69/100
# 176/176 [==============================] - 24s 134ms/step - loss: 0.8586 - accuracy: 0.6849 - val_loss: 1.1419 - val_accuracy: 0.5317
# Epoch 70/100
# 176/176 [==============================] - 23s 132ms/step - loss: 0.8822 - accuracy: 0.6719 - val_loss: 0.8281 - val_accuracy: 0.6954
# Epoch 71/100
# 176/176 [==============================] - 24s 137ms/step - loss: 0.8636 - accuracy: 0.6848 - val_loss: 1.0059 - val_accuracy: 0.5893
# Epoch 72/100
# 176/176 [==============================] - 25s 141ms/step - loss: 0.8640 - accuracy: 0.6874 - val_loss: 1.0741 - val_accuracy: 0.5751
# Epoch 73/100
# 176/176 [==============================] - 24s 135ms/step - loss: 0.8589 - accuracy: 0.6830 - val_loss: 0.8183 - val_accuracy: 0.7018
# Epoch 74/100
# 176/176 [==============================] - 25s 139ms/step - loss: 0.8491 - accuracy: 0.6897 - val_loss: 0.9320 - val_accuracy: 0.6342
# Epoch 75/100
# 176/176 [==============================] - 25s 140ms/step - loss: 0.8621 - accuracy: 0.6796 - val_loss: 0.8036 - val_accuracy: 0.7224
# Epoch 76/100
# 176/176 [==============================] - 24s 135ms/step - loss: 0.8469 - accuracy: 0.6873 - val_loss: 0.9738 - val_accuracy: 0.6128
# Epoch 77/100
# 176/176 [==============================] - 25s 140ms/step - loss: 0.8556 - accuracy: 0.6910 - val_loss: 0.8175 - val_accuracy: 0.7046
# Epoch 78/100
# 176/176 [==============================] - 24s 134ms/step - loss: 0.8657 - accuracy: 0.6835 - val_loss: 0.8637 - val_accuracy: 0.6705
# Epoch 79/100
# 176/176 [==============================] - 25s 140ms/step - loss: 0.8610 - accuracy: 0.6865 - val_loss: 0.7926 - val_accuracy: 0.7345
# Epoch 80/100
# 176/176 [==============================] - 25s 141ms/step - loss: 0.8626 - accuracy: 0.6869 - val_loss: 0.8861 - val_accuracy: 0.6527
# Epoch 81/100
# 176/176 [==============================] - 24s 135ms/step - loss: 0.8639 - accuracy: 0.6821 - val_loss: 0.8253 - val_accuracy: 0.7053
# Epoch 82/100
# 176/176 [==============================] - 24s 135ms/step - loss: 0.8760 - accuracy: 0.6734 - val_loss: 0.7977 - val_accuracy: 0.7046
# Epoch 83/100
# 176/176 [==============================] - 23s 133ms/step - loss: 0.8591 - accuracy: 0.6844 - val_loss: 0.8183 - val_accuracy: 0.7082
# Epoch 84/100
# 176/176 [==============================] - 24s 134ms/step - loss: 0.8553 - accuracy: 0.6892 - val_loss: 0.8416 - val_accuracy: 0.6819
# Epoch 85/100
# 176/176 [==============================] - 25s 140ms/step - loss: 0.8521 - accuracy: 0.6853 - val_loss: 0.9307 - val_accuracy: 0.6270
# Epoch 86/100
# 176/176 [==============================] - 24s 135ms/step - loss: 0.8501 - accuracy: 0.6881 - val_loss: 0.8299 - val_accuracy: 0.6961
# Epoch 87/100
# 176/176 [==============================] - 23s 131ms/step - loss: 0.8552 - accuracy: 0.6837 - val_loss: 0.7999 - val_accuracy: 0.7068
# Epoch 88/100
# 176/176 [==============================] - 24s 137ms/step - loss: 0.8481 - accuracy: 0.6874 - val_loss: 0.7775 - val_accuracy: 0.7374
# Epoch 89/100
# 176/176 [==============================] - 24s 138ms/step - loss: 0.8384 - accuracy: 0.6956 - val_loss: 0.7701 - val_accuracy: 0.7324
# Epoch 90/100
# 176/176 [==============================] - 25s 142ms/step - loss: 0.8454 - accuracy: 0.6865 - val_loss: 0.9649 - val_accuracy: 0.6157
# Epoch 91/100
# 176/176 [==============================] - 23s 132ms/step - loss: 0.8538 - accuracy: 0.6762 - val_loss: 0.8211 - val_accuracy: 0.6954
# Epoch 92/100
# 176/176 [==============================] - 24s 134ms/step - loss: 0.8456 - accuracy: 0.6880 - val_loss: 0.8832 - val_accuracy: 0.6626
# Epoch 93/100
# 176/176 [==============================] - 24s 136ms/step - loss: 0.8344 - accuracy: 0.6924 - val_loss: 0.8065 - val_accuracy: 0.7174
# Epoch 94/100
# 176/176 [==============================] - 25s 142ms/step - loss: 0.8449 - accuracy: 0.6842 - val_loss: 0.8104 - val_accuracy: 0.7039
# Epoch 95/100
# 176/176 [==============================] - 23s 133ms/step - loss: 0.8383 - accuracy: 0.6862 - val_loss: 0.8029 - val_accuracy: 0.7039
# Epoch 96/100
# 176/176 [==============================] - 24s 135ms/step - loss: 0.8475 - accuracy: 0.6844 - val_loss: 0.7709 - val_accuracy: 0.7288
# Epoch 97/100
# 176/176 [==============================] - 25s 140ms/step - loss: 0.8421 - accuracy: 0.6919 - val_loss: 0.7658 - val_accuracy: 0.7445
# Epoch 98/100
# 176/176 [==============================] - 25s 141ms/step - loss: 0.8228 - accuracy: 0.7079 - val_loss: 0.9645 - val_accuracy: 0.6036
# Epoch 99/100
# 176/176 [==============================] - 24s 136ms/step - loss: 0.8336 - accuracy: 0.6981 - val_loss: 0.8193 - val_accuracy: 0.6940
# Epoch 100/100
# 176/176 [==============================] - 23s 132ms/step - loss: 0.8505 - accuracy: 0.6901 - val_loss: 0.8448 - val_accuracy: 0.6769
# Total time taken:  2502.632443666458  seconds

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='train accuracy')
plt.plot(history.history['val_accuracy'], label='validation accuracy')
plt.legend()
plt.show()

plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='validation loss')
plt.legend()
plt.show()

# %%
y_pred = model.predict(X_test)
# Out:
# 44/44 [==============================] - 2s 35ms/step

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt

# Binarize the labels
y_test_bin = label_binarize(y_test, classes=[0, 1, 2, 3])

# Compute the predicted probabilities for each class
probas = model.predict(X_test)

# Compute the ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(4):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], probas[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test_bin.ravel(), probas.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Plot the ROC curves
plt.figure()
lw = 2
plt.plot(fpr["micro"], tpr["micro"], color='deeppink', lw=lw, label='micro-average ROC curve (area = {0:0.2f})'
         ''.format(roc_auc["micro"]))
colors = ['aqua', 'darkorange', 'cornflowerblue', 'purple']
for i, color in zip(range(4), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))
plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# 44/44 [==============================] - 2s 36ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report,accuracy_score,cohen_kappa_score

def evaluate_model(model, X_test, y_test, labels):
    # Make predictions on test data
    y_pred = model.predict(X_test)
    y_pred_labels = np.argmax(y_pred, axis=1)
    y_test_labels = np.argmax(y_test, axis=1)

    # Calculate the metrics
    loss, accuracy = model.evaluate(X_test, y_test)
    precision = accuracy_score(y_test_labels, y_pred_labels)*100
    kappa = cohen_kappa_score(y_test_labels, y_pred_labels)*100
    classification = classification_report(y_test_labels, y_pred_labels, target_names=labels)
    confusion = confusion_matrix(y_test_labels, y_pred_labels)
    accuracy=accuracy*100
    # Plot the confusion matrix
    fig, ax = plt.subplots(figsize=(10, 8))
    sns.heatmap(confusion, annot=True, cmap="Blues", fmt="d", xticklabels=labels, yticklabels=labels)
    ax.set_xlabel("Predicted Labels")
    ax.set_ylabel("True Labels")
    ax.set_title("Confusion Matrix")
    plt.show()

    # Print the classification report
    print("Classification Report:\n", classification)

    # Print the metrics
    print(f"Loss: {loss:.4f}")
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Kappa Score: {kappa:.4f}")
    return confusion, classification

# %%
target = ['glioma', 'meningioma', 'notumor', 'pituitary']
confusion, classification= evaluate_model(model, X_test, y_test, target)
# Out:
# 44/44 [==============================] - 2s 34ms/step
# 44/44 [==============================] - 2s 36ms/step - loss: 0.8448 - accuracy: 0.6769
# Classification Report:
#                precision    recall  f1-score   support
#
#       glioma       0.68      0.57      0.62       324
#   meningioma       0.67      0.48      0.56       329
#      notumor       0.64      0.95      0.76       400
#    pituitary       0.76      0.65      0.70       352
#
#     accuracy                           0.68      1405
#    macro avg       0.69      0.66      0.66      1405
# weighted avg       0.69      0.68      0.67      1405
#
# Loss: 0.8448
# Accuracy: 67.6868
# Precision: 67.6868
# Kappa Score: 56.4232

# %%
from tensorflow.keras.models import load_model
# Save the model to a file
model.save('resnet-tf1.h5')

# %%
# Get the list of trainable layers in the model
trainable_layers = [layer for layer in model.layers if layer.trainable]

# Print the summary of trainable layers only
print("Trainable layers summary:")
for layer in trainable_layers:
    print(layer.name, layer.trainable, layer.output_shape)
# Out:
# Trainable layers summary:
# global_average_pooling2d True (None, 2048)
# dense True (None, 1024)
# dense_1 True (None, 4)

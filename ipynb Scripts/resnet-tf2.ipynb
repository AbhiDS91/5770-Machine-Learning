# %%
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import keras
from keras.models import Sequential
from keras.layers import Conv2D, Lambda, MaxPooling2D # convolution layers
from keras.layers import Dense, Dropout, Flatten # core layers
from keras.layers import BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical

# %%
import os
import cv2

def resize_image(image_path):
    # Load the image and resize it to 128,128
    img = cv2.imread(image_path)
    img = cv2.resize(img, (128, 128), interpolation = cv2.INTER_AREA)
    return img

def read_dataset(dataset_path):
    # Create a list to store all the images
    images = []
    # Create a list to store the labels
    labels = []
    # Loop through the folders in the dataset path
    for folder in os.listdir(dataset_path):
        # Check if the folder is either 'Testing' or 'Training'
        if folder in ['Testing', 'Training']:
            # Create the path to the folder
            folder_path = os.path.join(dataset_path, folder)
            # Loop through the sub-folders in the folder
            for sub_folder in os.listdir(folder_path):
                # Check if the sub-folder is one of the four categories
                if sub_folder in ['glioma', 'meningioma', 'notumor', 'pituitary']:
                    # Create the path to the sub-folder
                    sub_folder_path = os.path.join(folder_path, sub_folder)
                    # Loop through the images in the sub-folder
                    for image_file in os.listdir(sub_folder_path):
                        # Check if the image is a .jpg file
                        if image_file.endswith('.jpg'):
                            # Create the path to the image
                            image_path = os.path.join(sub_folder_path, image_file)
                            # Resize the image and add it to the list of images
                            images.append(resize_image(image_path))
                            # Add the label to the list of labels
                            labels.append(sub_folder)
    return images, labels

# %%
# Call the read_dataset function to read the dataset
images, labels = read_dataset('/kaggle/input/brain-tumor-mri-dataset/')

# %%
target = ['glioma', 'meningioma', 'notumor', 'pituitary']

def text_to_index(text_labels):
    index_labels = []
    for label in text_labels:
        index_labels.append(target.index(label))
    return index_labels

labels = text_to_index(labels)

# %%
images=np.array(images)
labels=np.array(labels)
print(images.shape,labels.shape)
images = images / 255.0
# Out:
# (7023, 128, 128, 3) (7023,)

# %%
print(labels)
# Out:
# [3 3 3 ... 0 0 0]

# %%
from sklearn.model_selection import train_test_split
# Split the images and labels into training and testing sets, with a  test size
X_train, X_test, y_train, y_test = train_test_split(images,labels, test_size=0.2, random_state=42,stratify=labels)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (5618, 128, 128, 3) (1405, 128, 128, 3) (5618,) (1405,)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, Flatten, GlobalAveragePooling2D, BatchNormalization, Conv2D, MaxPooling2D
from tensorflow.keras.regularizers import l2,l1
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
from keras.applications import ResNet50

# Load the pre-trained ResNet50 model without top layers
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(128,128,3))

# Freeze the weights of the base model to prevent them from being updated during training
for layer in base_model.layers:
    layer.trainable = True
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 0s 0us/step

# %%
x =base_model.output
# Add remaining layers
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu', kernel_regularizer=l2(0.01))(x)
predictions = Dense(4, activation='softmax')(x)

# Define the model
model = Model(inputs=base_model.input, outputs=predictions)

# %%
adam = Adam(lr=0.005)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
import tensorflow as tf
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

checkpoint = ModelCheckpoint('best_model.h5', save_best_only=True)
early_stop = EarlyStopping(patience=20, restore_best_weights=True)
tensorboard = TensorBoard(log_dir='./logs')

# %%
y_train = to_categorical(y_train)
print(f"Label size {y_train.shape}")
y_test = to_categorical(y_test)
print(f"Label size {y_test.shape}")
# Out:
# Label size (5618, 4)
# Label size (1405, 4)

# %%
from keras.preprocessing.image import ImageDataGenerator

# Create an instance of ImageDataGenerator with rotation and flip parameters
datagen = ImageDataGenerator(rotation_range=15, horizontal_flip=True, vertical_flip=True)
# Fit the generator to your training data
datagen.fit(X_train)

# %%
import time

# start time
start_time = time.time()


history = model.fit(datagen.flow(X_train, y_train, batch_size=32), validation_data=(X_test, y_test), epochs=100, batch_size=32, callbacks=
# Epoch 38/100
# 176/176 [==============================] - 30s 171ms/step - loss: 0.0780 - accuracy: 0.9836 - val_loss: 0.7944 - val_accuracy: 0.8278
# Epoch 39/100
# 176/176 [==============================] - 30s 172ms/step - loss: 0.0488 - accuracy: 0.9897 - val_loss: 0.2631 - val_accuracy: 0.9196
# Epoch 40/100
# 176/176 [==============================] - 30s 168ms/step - loss: 0.0622 - accuracy: 0.9854 - val_loss: 0.5772 - val_accuracy: 0.7950
# Total time taken:  1244.9684262275696  seconds

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='train accuracy')
plt.plot(history.history['val_accuracy'], label='validation accuracy')
plt.legend()
plt.show()

plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='validation loss')
plt.legend()
plt.show()

# %%
y_pred = model.predict(X_test)
# Out:
# 44/44 [==============================] - 2s 36ms/step

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt

# Binarize the labels
y_test_bin = label_binarize(y_test, classes=[0, 1, 2, 3])

# Compute the predicted probabilities for each class
probas = model.predict(X_test)

# Compute the ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(4):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], probas[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test_bin.ravel(), probas.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Plot the ROC curves
plt.figure()
lw = 2
plt.plot(fpr["micro"], tpr["micro"], color='deeppink', lw=lw, label='micro-average ROC curve (area = {0:0.2f})'
         ''.format(roc_auc["micro"]))
colors = ['aqua', 'darkorange', 'cornflowerblue', 'purple']
for i, color in zip(range(4), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))
plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# 44/44 [==============================] - 2s 36ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report,accuracy_score,cohen_kappa_score

def evaluate_model(model, X_test, y_test, labels):
    # Make predictions on test data
    y_pred = model.predict(X_test)
    y_pred_labels = np.argmax(y_pred, axis=1)
    y_test_labels = np.argmax(y_test, axis=1)

    # Calculate the metrics
    loss, accuracy = model.evaluate(X_test, y_test)
    precision = accuracy_score(y_test_labels, y_pred_labels)*100
    kappa = cohen_kappa_score(y_test_labels, y_pred_labels)*100
    classification = classification_report(y_test_labels, y_pred_labels, target_names=labels)
    confusion = confusion_matrix(y_test_labels, y_pred_labels)
    accuracy=accuracy*100
    # Plot the confusion matrix
    fig, ax = plt.subplots(figsize=(10, 8))
    sns.heatmap(confusion, annot=True, cmap="Blues", fmt="d", xticklabels=labels, yticklabels=labels)
    ax.set_xlabel("Predicted Labels")
    ax.set_ylabel("True Labels")
    ax.set_title("Confusion Matrix")
    plt.show()

    # Print the classification report
    print("Classification Report:\n", classification)

    # Print the metrics
    print(f"Loss: {loss:.4f}")
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Kappa Score: {kappa:.4f}")
    return confusion, classification

# %%
target = ['glioma', 'meningioma', 'notumor', 'pituitary']
confusion, classification= evaluate_model(model, X_test, y_test, target)
# Out:
# 44/44 [==============================] - 2s 35ms/step
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1164 - accuracy: 0.9680
# Classification Report:
#                precision    recall  f1-score   support
#
#       glioma       0.96      0.96      0.96       324
#   meningioma       0.94      0.95      0.94       329
#      notumor       1.00      0.97      0.98       400
#    pituitary       0.97      0.99      0.98       352
#
#     accuracy                           0.97      1405
#    macro avg       0.97      0.97      0.97      1405
# weighted avg       0.97      0.97      0.97      1405
#
# Loss: 0.1164
# Accuracy: 96.7972
# Precision: 96.7972
# Kappa Score: 95.7208

# %%
from tensorflow.keras.models import load_model
# Save the model to a file
model.save('resnet-tf2.h5')

# %%
# Get the list of trainable layers in the model
trainable_layers = [layer for layer in model.layers if layer.trainable]

# Print the summary of trainable layers only
print("Trainable layers summary:")
for layer in trainable_layers:
    print(layer.name, layer.trainable, layer.output_shape)
# Out:
# Trainable layers summary:
# input_1 True [(None, 128, 128, 3)]
# conv1_pad True (None, 134, 134, 3)
# conv1_conv True (None, 64, 64, 64)
# conv1_bn True (None, 64, 64, 64)
# conv1_relu True (None, 64, 64, 64)
# pool1_pad True (None, 66, 66, 64)
# pool1_pool True (None, 32, 32, 64)
# conv2_block1_1_conv True (None, 32, 32, 64)
# conv2_block1_1_bn True (None, 32, 32, 64)
# conv2_block1_1_relu True (None, 32, 32, 64)
# conv2_block1_2_conv True (None, 32, 32, 64)
# conv2_block1_2_bn True (None, 32, 32, 64)
# conv2_block1_2_relu True (None, 32, 32, 64)
# conv2_block1_0_conv True (None, 32, 32, 256)
# conv2_block1_3_conv True (None, 32, 32, 256)
# conv2_block1_0_bn True (None, 32, 32, 256)
# conv2_block1_3_bn True (None, 32, 32, 256)
# conv2_block1_add True (None, 32, 32, 256)
# conv2_block1_out True (None, 32, 32, 256)
# conv2_block2_1_conv True (None, 32, 32, 64)
# conv2_block2_1_bn True (None, 32, 32, 64)
# conv2_block2_1_relu True (None, 32, 32, 64)
# conv2_block2_2_conv True (None, 32, 32, 64)
# conv2_block2_2_bn True (None, 32, 32, 64)
# conv2_block2_2_relu True (None, 32, 32, 64)
# conv2_block2_3_conv True (None, 32, 32, 256)
# conv2_block2_3_bn True (None, 32, 32, 256)
# conv2_block2_add True (None, 32, 32, 256)
# conv2_block2_out True (None, 32, 32, 256)
# conv2_block3_1_conv True (None, 32, 32, 64)
# conv2_block3_1_bn True (None, 32, 32, 64)
# conv2_block3_1_relu True (None, 32, 32, 64)
# conv2_block3_2_conv True (None, 32, 32, 64)
# conv2_block3_2_bn True (None, 32, 32, 64)
# conv2_block3_2_relu True (None, 32, 32, 64)
# conv2_block3_3_conv True (None, 32, 32, 256)
# conv2_block3_3_bn True (None, 32, 32, 256)
# conv2_block3_add True (None, 32, 32, 256)
# conv2_block3_out True (None, 32, 32, 256)
# conv3_block1_1_conv True (None, 16, 16, 128)
# conv3_block1_1_bn True (None, 16, 16, 128)
# conv3_block1_1_relu True (None, 16, 16, 128)
# conv3_block1_2_conv True (None, 16, 16, 128)
# conv3_block1_2_bn True (None, 16, 16, 128)
# conv3_block1_2_relu True (None, 16, 16, 128)
# conv3_block1_0_conv True (None, 16, 16, 512)
# conv3_block1_3_conv True (None, 16, 16, 512)
# conv3_block1_0_bn True (None, 16, 16, 512)
# conv3_block1_3_bn True (None, 16, 16, 512)
# conv3_block1_add True (None, 16, 16, 512)
# conv3_block1_out True (None, 16, 16, 512)
# conv3_block2_1_conv True (None, 16, 16, 128)
# conv3_block2_1_bn True (None, 16, 16, 128)
# conv3_block2_1_relu True (None, 16, 16, 128)
# conv3_block2_2_conv True (None, 16, 16, 128)
# conv3_block2_2_bn True (None, 16, 16, 128)
# conv3_block2_2_relu True (None, 16, 16, 128)
# conv3_block2_3_conv True (None, 16, 16, 512)
# conv3_block2_3_bn True (None, 16, 16, 512)
# conv3_block2_add True (None, 16, 16, 512)
# conv3_block2_out True (None, 16, 16, 512)
# conv3_block3_1_conv True (None, 16, 16, 128)
# conv3_block3_1_bn True (None, 16, 16, 128)
# conv3_block3_1_relu True (None, 16, 16, 128)
# conv3_block3_2_conv True (None, 16, 16, 128)
# conv3_block3_2_bn True (None, 16, 16, 128)
# conv3_block3_2_relu True (None, 16, 16, 128)
# conv3_block3_3_conv True (None, 16, 16, 512)
# conv3_block3_3_bn True (None, 16, 16, 512)
# conv3_block3_add True (None, 16, 16, 512)
# conv3_block3_out True (None, 16, 16, 512)
# conv3_block4_1_conv True (None, 16, 16, 128)
# conv3_block4_1_bn True (None, 16, 16, 128)
# conv3_block4_1_relu True (None, 16, 16, 128)
# conv3_block4_2_conv True (None, 16, 16, 128)
# conv3_block4_2_bn True (None, 16, 16, 128)
# conv3_block4_2_relu True (None, 16, 16, 128)
# conv3_block4_3_conv True (None, 16, 16, 512)
# conv3_block4_3_bn True (None, 16, 16, 512)
# conv3_block4_add True (None, 16, 16, 512)
# conv3_block4_out True (None, 16, 16, 512)
# conv4_block1_1_conv True (None, 8, 8, 256)
# conv4_block1_1_bn True (None, 8, 8, 256)
# conv4_block1_1_relu True (None, 8, 8, 256)
# conv4_block1_2_conv True (None, 8, 8, 256)
# conv4_block1_2_bn True (None, 8, 8, 256)
# conv4_block1_2_relu True (None, 8, 8, 256)
# conv4_block1_0_conv True (None, 8, 8, 1024)
# conv4_block1_3_conv True (None, 8, 8, 1024)
# conv4_block1_0_bn True (None, 8, 8, 1024)
# conv4_block1_3_bn True (None, 8, 8, 1024)
# conv4_block1_add True (None, 8, 8, 1024)
# conv4_block1_out True (None, 8, 8, 1024)
# conv4_block2_1_conv True (None, 8, 8, 256)
# conv4_block2_1_bn True (None, 8, 8, 256)
# conv4_block2_1_relu True (None, 8, 8, 256)
# conv4_block2_2_conv True (None, 8, 8, 256)
# conv4_block2_2_bn True (None, 8, 8, 256)
# conv4_block2_2_relu True (None, 8, 8, 256)
# conv4_block2_3_conv True (None, 8, 8, 1024)
# conv4_block2_3_bn True (None, 8, 8, 1024)
# conv4_block2_add True (None, 8, 8, 1024)
# conv4_block2_out True (None, 8, 8, 1024)
# conv4_block3_1_conv True (None, 8, 8, 256)
# conv4_block3_1_bn True (None, 8, 8, 256)
# conv4_block3_1_relu True (None, 8, 8, 256)
# conv4_block3_2_conv True (None, 8, 8, 256)
# conv4_block3_2_bn True (None, 8, 8, 256)
# conv4_block3_2_relu True (None, 8, 8, 256)
# conv4_block3_3_conv True (None, 8, 8, 1024)
# conv4_block3_3_bn True (None, 8, 8, 1024)
# conv4_block3_add True (None, 8, 8, 1024)
# conv4_block3_out True (None, 8, 8, 1024)
# conv4_block4_1_conv True (None, 8, 8, 256)
# conv4_block4_1_bn True (None, 8, 8, 256)
# conv4_block4_1_relu True (None, 8, 8, 256)
# conv4_block4_2_conv True (None, 8, 8, 256)
# conv4_block4_2_bn True (None, 8, 8, 256)
# conv4_block4_2_relu True (None, 8, 8, 256)
# conv4_block4_3_conv True (None, 8, 8, 1024)
# conv4_block4_3_bn True (None, 8, 8, 1024)
# conv4_block4_add True (None, 8, 8, 1024)
# conv4_block4_out True (None, 8, 8, 1024)
# conv4_block5_1_conv True (None, 8, 8, 256)
# conv4_block5_1_bn True (None, 8, 8, 256)
# conv4_block5_1_relu True (None, 8, 8, 256)
# conv4_block5_2_conv True (None, 8, 8, 256)
# conv4_block5_2_bn True (None, 8, 8, 256)
# conv4_block5_2_relu True (None, 8, 8, 256)
# conv4_block5_3_conv True (None, 8, 8, 1024)
# conv4_block5_3_bn True (None, 8, 8, 1024)
# conv4_block5_add True (None, 8, 8, 1024)
# conv4_block5_out True (None, 8, 8, 1024)
# conv4_block6_1_conv True (None, 8, 8, 256)
# conv4_block6_1_bn True (None, 8, 8, 256)
# conv4_block6_1_relu True (None, 8, 8, 256)
# conv4_block6_2_conv True (None, 8, 8, 256)
# conv4_block6_2_bn True (None, 8, 8, 256)
# conv4_block6_2_relu True (None, 8, 8, 256)
# conv4_block6_3_conv True (None, 8, 8, 1024)
# conv4_block6_3_bn True (None, 8, 8, 1024)
# conv4_block6_add True (None, 8, 8, 1024)
# conv4_block6_out True (None, 8, 8, 1024)
# conv5_block1_1_conv True (None, 4, 4, 512)
# conv5_block1_1_bn True (None, 4, 4, 512)
# conv5_block1_1_relu True (None, 4, 4, 512)
# conv5_block1_2_conv True (None, 4, 4, 512)
# conv5_block1_2_bn True (None, 4, 4, 512)
# conv5_block1_2_relu True (None, 4, 4, 512)
# conv5_block1_0_conv True (None, 4, 4, 2048)
# conv5_block1_3_conv True (None, 4, 4, 2048)
# conv5_block1_0_bn True (None, 4, 4, 2048)
# conv5_block1_3_bn True (None, 4, 4, 2048)
# conv5_block1_add True (None, 4, 4, 2048)
# conv5_block1_out True (None, 4, 4, 2048)
# conv5_block2_1_conv True (None, 4, 4, 512)
# conv5_block2_1_bn True (None, 4, 4, 512)
# conv5_block2_1_relu True (None, 4, 4, 512)
# conv5_block2_2_conv True (None, 4, 4, 512)
# conv5_block2_2_bn True (None, 4, 4, 512)
# conv5_block2_2_relu True (None, 4, 4, 512)
# conv5_block2_3_conv True (None, 4, 4, 2048)
# conv5_block2_3_bn True (None, 4, 4, 2048)
# conv5_block2_add True (None, 4, 4, 2048)
# conv5_block2_out True (None, 4, 4, 2048)
# conv5_block3_1_conv True (None, 4, 4, 512)
# conv5_block3_1_bn True (None, 4, 4, 512)
# conv5_block3_1_relu True (None, 4, 4, 512)
# conv5_block3_2_conv True (None, 4, 4, 512)
# conv5_block3_2_bn True (None, 4, 4, 512)
# conv5_block3_2_relu True (None, 4, 4, 512)
# conv5_block3_3_conv True (None, 4, 4, 2048)
# conv5_block3_3_bn True (None, 4, 4, 2048)
# conv5_block3_add True (None, 4, 4, 2048)
# conv5_block3_out True (None, 4, 4, 2048)
# global_average_pooling2d True (None, 2048)
# dense True (None, 1024)
# dense_1 True (None, 4)

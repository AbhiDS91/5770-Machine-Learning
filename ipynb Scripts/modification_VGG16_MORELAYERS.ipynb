# %%
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import keras
from keras.models import Sequential
from keras.layers import Conv2D, Lambda, MaxPooling2D # convolution layers
from keras.layers import Dense, Dropout, Flatten # core layers
from keras.layers import BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical

# %%
import os
import cv2

def resize_image(image_path):
    # Load the image and resize it to 128,128
    img = cv2.imread(image_path)
    img = cv2.resize(img, (128, 128), interpolation = cv2.INTER_AREA)
    return img

def read_dataset(dataset_path):
    # Create a list to store all the images
    images = []
    # Create a list to store the labels
    labels = []
    # Loop through the folders in the dataset path
    for folder in os.listdir(dataset_path):
        # Check if the folder is either 'Testing' or 'Training'
        if folder in ['Testing', 'Training']:
            # Create the path to the folder
            folder_path = os.path.join(dataset_path, folder)
            # Loop through the sub-folders in the folder
            for sub_folder in os.listdir(folder_path):
                # Check if the sub-folder is one of the four categories
                if sub_folder in ['glioma', 'meningioma', 'notumor', 'pituitary']:
                    # Create the path to the sub-folder
                    sub_folder_path = os.path.join(folder_path, sub_folder)
                    # Loop through the images in the sub-folder
                    for image_file in os.listdir(sub_folder_path):
                        # Check if the image is a .jpg file
                        if image_file.endswith('.jpg'):
                            # Create the path to the image
                            image_path = os.path.join(sub_folder_path, image_file)
                            # Resize the image and add it to the list of images
                            images.append(resize_image(image_path))
                            # Add the label to the list of labels
                            labels.append(sub_folder)
    return images, labels

# %%
# Call the read_dataset function to read the dataset
images, labels = read_dataset('/kaggle/input/brain-tumor-mri-dataset/')

# %%
target = ['glioma', 'meningioma', 'notumor', 'pituitary']

def text_to_index(text_labels):
    index_labels = []
    for label in text_labels:
        index_labels.append(target.index(label))
    return index_labels

labels = text_to_index(labels)

# %%
images=np.array(images)
labels=np.array(labels)
print(images.shape,labels.shape)
images = images / 255.0
# Out:
# (7023, 128, 128, 3) (7023,)

# %%
print(labels)
# Out:
# [3 3 3 ... 0 0 0]

# %%
from sklearn.model_selection import train_test_split
# Split the images and labels into training and testing sets, with a  test size
X_train, X_test, y_train, y_test = train_test_split(images,labels, test_size=0.2, random_state=42,stratify=labels)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (5618, 128, 128, 3) (1405, 128, 128, 3) (5618,) (1405,)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, Flatten, GlobalAveragePooling2D, BatchNormalization, Conv2D, MaxPooling2D
from tensorflow.keras.regularizers import l2,l1
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg16 import VGG16

# Load the VGG16 model with pre-trained ImageNet weights
base_model = VGG16(weights=None, include_top=False, input_shape=(128, 128, 3))

# Make the layers traiable 
for layer in base_model.layers:
    layer.trainable = False

# %%
# Add convolutional layers
x = Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same')(base_model.output)
x = Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.01))(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same', kernel_regularizer=l1(0.01))(x)
x = Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same', kernel_regularizer=l1(0.01))(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

# Add remaining layers
x = GlobalAveragePooling2D()(x)
x = Dense(512, activation='relu', kernel_regularizer=l1(0.01))(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Flatten()(x)
x = Dense(256, activation='relu', kernel_regularizer=l2(0.01))(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(64, activation='relu', kernel_regularizer=l1(0.01))(x)
x = Dropout(0.5)(x)
x = Dense(16, activation='relu', kernel_regularizer=l2(0.01))(x)
x = Dense(8, activation='relu', kernel_regularizer=l2(0.01))(x)
predictions = Dense(4, activation='softmax')(x)

# Define the model
model = Model(inputs=base_model.input, outputs=predictions)


# Print the model summary
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 128, 128, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 128, 128, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 64, 64, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 64, 64, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 64, 64, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 32, 32, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 32, 32, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 32, 32, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 32, 32, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 16, 16, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 16, 16, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
#  conv2d_4 (Conv2D)           (None, 4, 4, 64)          294976
#
#  conv2d_5 (Conv2D)           (None, 4, 4, 64)          36928
#
#  max_pooling2d_2 (MaxPooling  (None, 2, 2, 64)         0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 2, 2, 32)          18464
#
#  conv2d_7 (Conv2D)           (None, 2, 2, 32)          9248
#
#  max_pooling2d_3 (MaxPooling  (None, 1, 1, 32)         0
#  2D)
#
#  global_average_pooling2d_1   (None, 32)               0
#  (GlobalAveragePooling2D)
#
#  dense_6 (Dense)             (None, 512)               16896
#
#  batch_normalization_2 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_7 (Dense)             (None, 256)               131328
#
#  batch_normalization_3 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_8 (Dense)             (None, 64)                16448
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_9 (Dense)             (None, 16)                1040
#
#  dense_10 (Dense)            (None, 8)                 136
#
#  dense_11 (Dense)            (None, 4)                 36
#
# =================================================================
# Total params: 15,243,260
# Trainable params: 527,036
# Non-trainable params: 14,716,224
# _________________________________________________________________

# %%
adam = Adam(lr=0.005)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
import tensorflow as tf
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

checkpoint = ModelCheckpoint('best_model.h5', save_best_only=True)
early_stop = EarlyStopping(patience=20, restore_best_weights=True)
tensorboard = TensorBoard(log_dir='./logs')

# %%
y_train = to_categorical(y_train)
print(f"Label size {y_train.shape}")
y_test = to_categorical(y_test)
print(f"Label size {y_test.shape}")
# Out:
# Label size (5618, 4)
# Label size (1405, 4)

# %%
from keras.preprocessing.image import ImageDataGenerator

# Create an instance of ImageDataGenerator with rotation and flip parameters
datagen = ImageDataGenerator(rotation_range=15, horizontal_flip=True, vertical_flip=True)
# Fit the generator to your training data
datagen.fit(X_train)

# %%
import time

# start time
start_time = time.time()


history = model.fit(datagen.flow(X_train, y_train, batch_size=32), validation_data=(X_test, y_test), epochs=100, batch_size=32, callbacks=[checkpoint, early_stop])

# end time
end_time = time.time()

# calculate total time taken
total_time = end_time - start_time

print("Total time taken: ", total_time, " seconds")
# Out:
# Epoch 1/100
# 176/176 [==============================] - 41s 187ms/step - loss: 9.7392 - accuracy: 0.4669 - val_loss: 1.8693 - val_accuracy: 0.2370
# Epoch 2/100
# 176/176 [==============================] - 28s 157ms/step - loss: 1.5184 - accuracy: 0.4726 - val_loss: 1.6339 - val_accuracy: 0.3900
# Epoch 3/100
# 176/176 [==============================] - 27s 151ms/step - loss: 1.3810 - accuracy: 0.4957 - val_loss: 1.9581 - val_accuracy: 0.2847
# Epoch 4/100
# 176/176 [==============================] - 27s 151ms/step - loss: 1.3058 - accuracy: 0.5133 - val_loss: 1.9890 - val_accuracy: 0.2847
# Epoch 5/100
# 176/176 [==============================] - 27s 150ms/step - loss: 1.2630 - accuracy: 0.5125 - val_loss: 1.7796 - val_accuracy: 0.3260
# Epoch 6/100
# 176/176 [==============================] - 27s 153ms/step - loss: 1.2356 - accuracy: 0.5281 - val_loss: 3.6450 - val_accuracy: 0.2847
# Epoch 7/100
# 176/176 [==============================] - 26s 150ms/step - loss: 1.1928 - accuracy: 0.5219 - val_loss: 2.0036 - val_accuracy: 0.2826
# Epoch 8/100
# 176/176 [==============================] - 27s 155ms/step - loss: 1.1834 - accuracy: 0.5319 - val_loss: 1.5097 - val_accuracy: 0.4178
# Epoch 9/100
# 176/176 [==============================] - 27s 155ms/step - loss: 1.1747 - accuracy: 0.5310 - val_loss: 1.1182 - val_accuracy: 0.5224
# Epoch 10/100
# 176/176 [==============================] - 26s 149ms/step - loss: 1.1564 - accuracy: 0.5279 - val_loss: 1.6197 - val_accuracy: 0.3886
# Epoch 11/100
# 176/176 [==============================] - 27s 154ms/step - loss: 1.1611 - accuracy: 0.5363 - val_loss: 1.7687 - val_accuracy: 0.3580
# Epoch 12/100
# 176/176 [==============================] - 26s 149ms/step - loss: 1.1415 - accuracy: 0.5516 - val_loss: 1.3169 - val_accuracy: 0.4448
# Epoch 13/100
# 176/176 [==============================] - 27s 153ms/step - loss: 1.1470 - accuracy: 0.5486 - val_loss: 2.5032 - val_accuracy: 0.2854
# Epoch 14/100
# 176/176 [==============================] - 27s 153ms/step - loss: 1.1184 - accuracy: 0.5769 - val_loss: 2.4965 - val_accuracy: 0.2904
# Epoch 15/100
# 176/176 [==============================] - 27s 154ms/step - loss: 1.1249 - accuracy: 0.5701 - val_loss: 1.0697 - val_accuracy: 0.5915
# Epoch 16/100
# 176/176 [==============================] - 26s 150ms/step - loss: 1.1188 - accuracy: 0.5780 - val_loss: 1.7678 - val_accuracy: 0.3851
# Epoch 17/100
# 176/176 [==============================] - 26s 149ms/step - loss: 1.1028 - accuracy: 0.5929 - val_loss: 1.7516 - val_accuracy: 0.3523
# Epoch 18/100
# 176/176 [==============================] - 26s 150ms/step - loss: 1.0847 - accuracy: 0.6123 - val_loss: 1.2219 - val_accuracy: 0.5324
# Epoch 19/100
# 176/176 [==============================] - 27s 153ms/step - loss: 1.1006 - accuracy: 0.6088 - val_loss: 1.3570 - val_accuracy: 0.4612
# Epoch 20/100
# 176/176 [==============================] - 26s 149ms/step - loss: 1.0946 - accuracy: 0.6193 - val_loss: 1.0951 - val_accuracy: 0.6370
# Epoch 21/100
# 176/176 [==============================] - 26s 150ms/step - loss: 1.0850 - accuracy: 0.6274 - val_loss: 2.0805 - val_accuracy: 0.3160
# Epoch 22/100
# 176/176 [==============================] - 26s 149ms/step - loss: 1.0693 - accuracy: 0.6415 - val_loss: 1.8014 - val_accuracy: 0.4100
# Epoch 23/100
# 176/176 [==============================] - 26s 145ms/step - loss: 1.0826 - accuracy: 0.6235 - val_loss: 1.4632 - val_accuracy: 0.4555
# Epoch 24/100
# 176/176 [==============================] - 26s 149ms/step - loss: 1.0709 - accuracy: 0.6383 - val_loss: 3.7349 - val_accuracy: 0.2527
# Epoch 25/100
# 176/176 [==============================] - 27s 154ms/step - loss: 1.0644 - accuracy: 0.6369 - val_loss: 0.9632 - val_accuracy: 0.6904
# Epoch 26/100
# 176/176 [==============================] - 27s 152ms/step - loss: 1.0472 - accuracy: 0.6396 - val_loss: 2.0329 - val_accuracy: 0.3331
# Epoch 27/100
# 176/176 [==============================] - 26s 149ms/step - loss: 1.0653 - accuracy: 0.6335 - val_loss: 1.5948 - val_accuracy: 0.4413
# Epoch 28/100
# 176/176 [==============================] - 26s 148ms/step - loss: 1.0606 - accuracy: 0.6333 - val_loss: 1.4545 - val_accuracy: 0.4875
# Epoch 29/100
# 176/176 [==============================] - 26s 148ms/step - loss: 1.0552 - accuracy: 0.6502 - val_loss: 2.0826 - val_accuracy: 0.3957
# Epoch 30/100
# 176/176 [==============================] - 27s 152ms/step - loss: 1.0422 - accuracy: 0.6554 - val_loss: 3.7014 - val_accuracy: 0.2854
# Epoch 31/100
# 176/176 [==============================] - 26s 148ms/step - loss: 1.0412 - accuracy: 0.6582 - val_loss: 1.8940 - val_accuracy: 0.4142
# Epoch 32/100
# 176/176 [==============================] - 26s 148ms/step - loss: 1.0408 - accuracy: 0.6549 - val_loss: 1.1939 - val_accuracy: 0.5516
# Epoch 33/100
# 176/176 [==============================] - 26s 148ms/step - loss: 1.0325 - accuracy: 0.6570 - val_loss: 1.0210 - val_accuracy: 0.6612
# Epoch 34/100
# 176/176 [==============================] - 27s 153ms/step - loss: 1.0546 - accuracy: 0.6474 - val_loss: 2.7836 - val_accuracy: 0.3011
# Epoch 35/100
# 176/176 [==============================] - 26s 146ms/step - loss: 1.0185 - accuracy: 0.6616 - val_loss: 1.4364 - val_accuracy: 0.4989
# Epoch 36/100
# 176/176 [==============================] - 27s 153ms/step - loss: 1.0132 - accuracy: 0.6648 - val_loss: 1.2972 - val_accuracy: 0.5181
# Epoch 37/100
# 176/176 [==============================] - 27s 151ms/step - loss: 1.0295 - accuracy: 0.6550 - val_loss: 3.1796 - val_accuracy: 0.2875
# Epoch 38/100
# 176/176 [==============================] - 27s 154ms/step - loss: 1.0070 - accuracy: 0.6618 - val_loss: 1.0215 - val_accuracy: 0.6178
# Epoch 39/100
# 176/176 [==============================] - 26s 148ms/step - loss: 0.9924 - accuracy: 0.6753 - val_loss: 2.4016 - val_accuracy: 0.3267
# Epoch 40/100
# 176/176 [==============================] - 27s 151ms/step - loss: 1.0112 - accuracy: 0.6671 - val_loss: 4.8951 - val_accuracy: 0.2847
# Epoch 41/100
# 176/176 [==============================] - 27s 151ms/step - loss: 1.0265 - accuracy: 0.6545 - val_loss: 1.0000 - val_accuracy: 0.6534
# Epoch 42/100
# 176/176 [==============================] - 26s 150ms/step - loss: 0.9952 - accuracy: 0.6775 - val_loss: 1.0253 - val_accuracy: 0.6420
# Epoch 43/100
# 176/176 [==============================] - 27s 151ms/step - loss: 1.0004 - accuracy: 0.6630 - val_loss: 2.7745 - val_accuracy: 0.3495
# Epoch 44/100
# 176/176 [==============================] - 26s 148ms/step - loss: 0.9930 - accuracy: 0.6682 - val_loss: 4.4529 - val_accuracy: 0.3103
# Epoch 45/100
# 176/176 [==============================] - 27s 154ms/step - loss: 0.9863 - accuracy: 0.6702 - val_loss: 0.9124 - val_accuracy: 0.7324
# Epoch 46/100
# 176/176 [==============================] - 27s 151ms/step - loss: 0.9881 - accuracy: 0.6725 - val_loss: 2.7459 - val_accuracy: 0.3039
# Epoch 47/100
# 176/176 [==============================] - 26s 147ms/step - loss: 0.9735 - accuracy: 0.6752 - val_loss: 1.0252 - val_accuracy: 0.6626
# Epoch 48/100
# 176/176 [==============================] - 27s 151ms/step - loss: 0.9885 - accuracy: 0.6737 - val_loss: 1.3025 - val_accuracy: 0.5039
# Epoch 49/100
# 176/176 [==============================] - 27s 154ms/step - loss: 0.9802 - accuracy: 0.6782 - val_loss: 1.4314 - val_accuracy: 0.5089
# Epoch 50/100
# 176/176 [==============================] - 27s 153ms/step - loss: 0.9839 - accuracy: 0.6791 - val_loss: 5.3502 - val_accuracy: 0.2847
# Epoch 51/100
# 176/176 [==============================] - 26s 150ms/step - loss: 0.9732 - accuracy: 0.6819 - val_loss: 4.0408 - val_accuracy: 0.2861
# Epoch 52/100
# 176/176 [==============================] - 26s 150ms/step - loss: 0.9709 - accuracy: 0.6844 - val_loss: 5.6126 - val_accuracy: 0.2847
# Epoch 53/100
# 176/176 [==============================] - 27s 156ms/step - loss: 0.9698 - accuracy: 0.6764 - val_loss: 1.0725 - val_accuracy: 0.6384
# Epoch 54/100
# 176/176 [==============================] - 26s 150ms/step - loss: 0.9688 - accuracy: 0.6841 - val_loss: 3.8382 - val_accuracy: 0.2875
# Epoch 55/100
# 176/176 [==============================] - 28s 156ms/step - loss: 0.9615 - accuracy: 0.6853 - val_loss: 0.8511 - val_accuracy: 0.7495
# Epoch 56/100
# 176/176 [==============================] - 26s 150ms/step - loss: 0.9584 - accuracy: 0.6860 - val_loss: 0.9274 - val_accuracy: 0.7096
# Epoch 57/100
# 176/176 [==============================] - 27s 151ms/step - loss: 0.9791 - accuracy: 0.6670 - val_loss: 2.4133 - val_accuracy: 0.3139
# Epoch 58/100
# 176/176 [==============================] - 26s 150ms/step - loss: 0.9789 - accuracy: 0.6794 - val_loss: 0.8574 - val_accuracy: 0.7495
# Epoch 59/100
# 176/176 [==============================] - 26s 148ms/step - loss: 0.9719 - accuracy: 0.6796 - val_loss: 0.8771 - val_accuracy: 0.7310
# Epoch 60/100
# 176/176 [==============================] - 26s 149ms/step - loss: 0.9828 - accuracy: 0.6814 - val_loss: 1.5067 - val_accuracy: 0.4811
# Epoch 61/100
# 176/176 [==============================] - 27s 152ms/step - loss: 0.9611 - accuracy: 0.6769 - val_loss: 1.6539 - val_accuracy: 0.4811
# Epoch 62/100
# 176/176 [==============================] - 27s 150ms/step - loss: 0.9599 - accuracy: 0.6819 - val_loss: 1.1058 - val_accuracy: 0.6036
# Epoch 63/100
# 176/176 [==============================] - 26s 146ms/step - loss: 0.9586 - accuracy: 0.6903 - val_loss: 0.9715 - val_accuracy: 0.6591
# Epoch 64/100
# 176/176 [==============================] - 26s 150ms/step - loss: 0.9587 - accuracy: 0.6926 - val_loss: 2.5070 - val_accuracy: 0.3786
# Epoch 65/100
# 176/176 [==============================] - 26s 150ms/step - loss: 0.9459 - accuracy: 0.6917 - val_loss: 1.9379 - val_accuracy: 0.4356
# Epoch 66/100
# 176/176 [==============================] - 27s 154ms/step - loss: 0.9545 - accuracy: 0.6841 - val_loss: 1.8225 - val_accuracy: 0.4925
# Epoch 67/100
# 176/176 [==============================] - 26s 149ms/step - loss: 0.9476 - accuracy: 0.6842 - val_loss: 1.3238 - val_accuracy: 0.5196
# Epoch 68/100
# 176/176 [==============================] - 27s 154ms/step - loss: 0.9432 - accuracy: 0.6855 - val_loss: 1.6633 - val_accuracy: 0.4790
# Epoch 69/100
# 176/176 [==============================] - 27s 155ms/step - loss: 0.9294 - accuracy: 0.6970 - val_loss: 1.4736 - val_accuracy: 0.5053
# Epoch 70/100
# 176/176 [==============================] - 26s 146ms/step - loss: 0.9615 - accuracy: 0.6871 - val_loss: 2.2516 - val_accuracy: 0.3808
# Epoch 71/100
# 176/176 [==============================] - 26s 150ms/step - loss: 0.9438 - accuracy: 0.6942 - val_loss: 1.1823 - val_accuracy: 0.5637
# Epoch 72/100
# 176/176 [==============================] - 27s 154ms/step - loss: 0.9264 - accuracy: 0.7024 - val_loss: 1.9158 - val_accuracy: 0.4477
# Epoch 73/100
# 176/176 [==============================] - 26s 150ms/step - loss: 0.9394 - accuracy: 0.6844 - val_loss: 0.8979 - val_accuracy: 0.7146
# Epoch 74/100
# 176/176 [==============================] - 27s 154ms/step - loss: 0.9307 - accuracy: 0.6994 - val_loss: 1.0767 - val_accuracy: 0.6541
# Epoch 75/100
# 176/176 [==============================] - 27s 155ms/step - loss: 0.9583 - accuracy: 0.6824 - val_loss: 0.9258 - val_accuracy: 0.7025
# Total time taken:  2024.8894793987274  seconds

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='train accuracy')
plt.plot(history.history['val_accuracy'], label='validation accuracy')
plt.legend()
plt.show()

plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='validation loss')
plt.legend()
plt.show()

# %%
y_pred = model.predict(X_test)
# Out:
# 44/44 [==============================] - 2s 42ms/step

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt

# Binarize the labels
y_test_bin = label_binarize(y_test, classes=[0, 1, 2, 3])

# Compute the predicted probabilities for each class
probas = model.predict(X_test)

# Compute the ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(4):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], probas[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test_bin.ravel(), probas.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Plot the ROC curves
plt.figure()
lw = 2
plt.plot(fpr["micro"], tpr["micro"], color='deeppink', lw=lw, label='micro-average ROC curve (area = {0:0.2f})'
         ''.format(roc_auc["micro"]))
colors = ['aqua', 'darkorange', 'cornflowerblue', 'purple']
for i, color in zip(range(4), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))
plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# 44/44 [==============================] - 2s 42ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report,accuracy_score,cohen_kappa_score

def evaluate_model(model, X_test, y_test, labels):
    # Make predictions on test data
    y_pred = model.predict(X_test)
    y_pred_labels = np.argmax(y_pred, axis=1)
    y_test_labels = np.argmax(y_test, axis=1)

    # Calculate the metrics
    loss, accuracy = model.evaluate(X_test, y_test)
    precision = accuracy_score(y_test_labels, y_pred_labels)*100
    kappa = cohen_kappa_score(y_test_labels, y_pred_labels)*100
    classification = classification_report(y_test_labels, y_pred_labels, target_names=labels)
    confusion = confusion_matrix(y_test_labels, y_pred_labels)
    accuracy=accuracy*100
    # Plot the confusion matrix
    fig, ax = plt.subplots(figsize=(10, 8))
    sns.heatmap(confusion, annot=True, cmap="Blues", fmt="d", xticklabels=labels, yticklabels=labels)
    ax.set_xlabel("Predicted Labels")
    ax.set_ylabel("True Labels")
    ax.set_title("Confusion Matrix")
    plt.show()

    # Print the classification report
    print("Classification Report:\n", classification)

    # Print the metrics
    print(f"Loss: {loss:.4f}")
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Kappa Score: {kappa:.4f}")
    return confusion, classification

# %%
target = ['glioma', 'meningioma', 'notumor', 'pituitary']
confusion, classification= evaluate_model(model, X_test, y_test, target)
# Out:
# 44/44 [==============================] - 2s 41ms/step
# 44/44 [==============================] - 2s 46ms/step - loss: 0.8511 - accuracy: 0.7495
# Classification Report:
#                precision    recall  f1-score   support
#
#       glioma       0.54      0.75      0.63       324
#   meningioma       0.60      0.33      0.43       329
#      notumor       0.92      0.95      0.93       400
#    pituitary       0.88      0.91      0.90       352
#
#     accuracy                           0.75      1405
#    macro avg       0.74      0.74      0.72      1405
# weighted avg       0.75      0.75      0.74      1405
#
# Loss: 0.8511
# Accuracy: 74.9466
# Precision: 74.9466
# Kappa Score: 66.5033

# %%
from tensorflow.keras.models import load_model
# Save the model to a file
model.save('mri_VGG_modified.h5')

# %%
# Get the list of trainable layers in the model
trainable_layers = [layer for layer in model.layers if layer.trainable]

# Print the summary of trainable layers only
print("Trainable layers summary:")
for layer in trainable_layers:
    print(layer.name, layer.trainable, layer.output_shape)
# Out:
# Trainable layers summary:
# conv2d_4 True (None, 4, 4, 64)
# conv2d_5 True (None, 4, 4, 64)
# max_pooling2d_2 True (None, 2, 2, 64)
# conv2d_6 True (None, 2, 2, 32)
# conv2d_7 True (None, 2, 2, 32)
# max_pooling2d_3 True (None, 1, 1, 32)
# global_average_pooling2d_1 True (None, 32)
# dense_6 True (None, 512)
# batch_normalization_2 True (None, 512)
# dropout_3 True (None, 512)
# flatten_1 True (None, 512)
# dense_7 True (None, 256)
# batch_normalization_3 True (None, 256)
# dropout_4 True (None, 256)
# dense_8 True (None, 64)
# dropout_5 True (None, 64)
# dense_9 True (None, 16)
# dense_10 True (None, 8)
# dense_11 True (None, 4)
